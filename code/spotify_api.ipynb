# %%
import sys
import spotipy
import spotipy.util as util

import re
import pandas as pd
import numpy as np

import config

# %% [markdown]
# # Spotify API Authorization

# %%
#loading in client id and secret provided by Spotify
client_id=config.client_id
client_secret=config.client_secret

#set my redirect url to google
redirect_uri="https://google.com/"

username=config.username

# %%
scope = 'user-library-read'

# %%
# if len(sys.argv) > 1:
#     username = sys.argv[1]
# else:
#    print(": %s username" % (sys.argv[0],))
#    sys.exit()

token = util.prompt_for_user_token(username,scope,client_id,client_secret,redirect_uri)

# %%
sp = spotipy.Spotify(auth=token)

# %%
#creating blank spotify dataframe
df = pd.DataFrame(columns=['id', 'name', 'artists', 'danceability',
                           'energy','key','loudness','mode','speechiness',
                           'acousticness','instrumentalness','liveness','valence',
                           'tempo','duration_ms','time_signature'])

# %%
def music(uri, name, artists):
    global df
    global top2017
    response = str(sp.audio_features(uri)[0])
    response = response[1:-1]
    response = response.split(",")
    response.pop(11)
    response.pop(11)
    response.pop(11)
    response.pop(11)
    response.pop(11)
    features = [uri, name, artists]
    for x in response:
        m = re.search("\d",x)
        if m:
            if "," in x:
                x = x[:-1]
            if x[m.start()-1] == "-":
                feature = x[m.start()-1:]
            else:
                feature = x[m.start():]
            try:
                feature = float(feature)
            except ValueError:
                feature = feature
            features.append(feature)
    df.loc[df.shape[0]] =  [features[0][:-1],features[1],features[2],features[3],features[4],features[5],features[6],features[7],features[8],features[9],features[10],features[11],features[12],features[13],features[14],features[15]]

def track_info(tracks):
    idlist = []
    for i, item in enumerate(tracks['items']):
        track = item['track']
        idlist.append([track['id'],track['name'],track['artists'][0]['name']])
        #print(" %d %32.32s %s" % (i, track['artists'][0]['name'],track['name']))
    return idlist

# %%
sp.audio_features('spotify:track:2EGaDf0cPX789H3LNeB03D')[0]
# Out:
# {'danceability': 0.666,
#  'energy': 0.871,
#  'key': 1,
#  'loudness': -6.017,
#  'mode': 0,
#  'speechiness': 0.0272,
#  'acousticness': 0.27,
#  'instrumentalness': 0.0208,
#  'liveness': 0.263,
#  'valence': 0.936,
#  'tempo': 108.501,
#  'type': 'audio_features',
#  'id': '2EGaDf0cPX789H3LNeB03D',
#  'uri': 'spotify:track:2EGaDf0cPX789H3LNeB03D',
#  'track_href': 'https://api.spotify.com/v1/tracks/2EGaDf0cPX789H3LNeB03D',
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2EGaDf0cPX789H3LNeB03D',
#  'duration_ms': 215326,
#  'time_signature': 4}

# %%
import requests
import warnings
import time

# %%
track_uri="spotify:track:2EGaDf0cPX789H3LNeB03D"

# %%
requests.get("https://api.spotify.com/v1/tracks/spotify:track:2EGaDf0cPX789H3LNeB03D")
# Out:
# <Response [401]>

# %%
response = requests.get("https://api.spotify.com/v1/tracks/spotify:track:2EGaDf0cPX789H3LNeB03D",
                        headers={'Authorization':'Bearer BQCEvtOUFDb2BTf_V0q0j_f7rsyR7Yju_FwFsLlYtUrM2CjQDK5cFAhnPOSxySc93IlbSu24cKKrP4hQrt2LYwlASl6eyURETX82Bfa9SWRRpYFCwdsE-kPLiF4HbfxPdhtz6PsXRq4PAcueDcpoFy3c3g'})

# %%
response
# Out:
# <Response [400]>

# %%
import pprint

# %%
#search on spotify
if len(sys.argv) > 1:
    search_str = sys.argv[1]
else:
    search_str = 'Radiohead'

result = sp.search(search_str)
pprint.pprint(result)
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=-f&type=track&market=US&offset=0&limit=10',
#             'items': [{'album': {'album_type': 'album',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4r63FhuTkUYltbVAg5TQnk'},
#                                               'href': 'https://api.spotify.com/v1/artists/4r63FhuTkUYltbVAg5TQnk',
#                                               'id': '4r63FhuTkUYltbVAg5TQnk',
#                                               'name': 'DaBaby',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:4r63FhuTkUYltbVAg5TQnk'}],
#                                  'available_markets': ['AD',
#                                                        'AE',
#                                                        'AR',
#                                                        'AT',
# ...

# %%
#checking content of spotify search
result['tracks']['items'][0]
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4r63FhuTkUYltbVAg5TQnk'},
#     'href': 'https://api.spotify.com/v1/artists/4r63FhuTkUYltbVAg5TQnk',
#     'id': '4r63FhuTkUYltbVAg5TQnk',
#     'name': 'DaBaby',
#     'type': 'artist',
#     'uri': 'spotify:artist:4r63FhuTkUYltbVAg5TQnk'}],
#   'available_markets': ['AD',
#    'AE',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
# ...

# %%
sys.argv[1]
# Out:
# '-f'

# %%
# #search on spotify
# if len(sys.argv) > 1:
#     search_str = sys.argv[1]
# else:
#     search_str = 'Radiohead'

# result = sp.search(search_str)
# pprint.pprint(result)

# if len(sys.argv) > 1:
#     urn = sys.argv[1]
# else:
#     urn = 'spotify:track:2EGaDf0cPX789H3LNeB03D'

#this is how we get the album name
urn = 'spotify:track:2EGaDf0cPX789H3LNeB03D'

tracks = sp.track(urn)
pprint.pprint(tracks)
# Out:
# {'album': {'album_type': 'album',
#            'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3sc7iUG1Wwpwx7bHeZolgx'},
#                         'href': 'https://api.spotify.com/v1/artists/3sc7iUG1Wwpwx7bHeZolgx',
#                         'id': '3sc7iUG1Wwpwx7bHeZolgx',
#                         'name': 'Bananarama',
#                         'type': 'artist',
#                         'uri': 'spotify:artist:3sc7iUG1Wwpwx7bHeZolgx'}],
#            'available_markets': ['AD',
#                                  'AE',
#                                  'AR',
#                                  'AT',
#                                  'AU',
#                                  'BE',
#                                  'BG',
#                                  'BH',
#                                  'BO',
#                                  'BR',
#                                  'CA',
#                                  'CH',
# ...

# %%
#how to get album name
tracks['album']['name']
# Out:
# "Bananarama (Collector's Edition)"

# %%
#list of genres available for the recommendations function
sp.recommendation_genre_seeds()
# Out:
# {'genres': ['acoustic',
#   'afrobeat',
#   'alt-rock',
#   'alternative',
#   'ambient',
#   'anime',
#   'black-metal',
#   'bluegrass',
#   'blues',
#   'bossanova',
#   'brazil',
#   'breakbeat',
#   'british',
#   'cantopop',
#   'chicago-house',
#   'children',
#   'chill',
#   'classical',
#   'club',
#   'comedy',
#   'country',
#   'dance',
#   'dancehall',
#   'death-metal',
#   'deep-house',
#   'detroit-techno',
#   'disco',
#   'disney',
#   'drum-and-bass',
#   'dub',
#   'dubstep',
#   'edm',
#   'electro',
#   'electronic',
#   'emo',
#   'folk',
#   'forro',
#   'french',
#   'funk',
#   'garage',
#   'german',
#   'gospel',
#   'goth',
#   'grindcore',
#   'groove',
#   'grunge',
#   'guitar',
#   'happy',
#   'hard-rock',
#   'hardcore',
#   'hardstyle',
#   'heavy-metal',
#   'hip-hop',
#   'holidays',
#   'honky-tonk',
#   'house',
#   'idm',
#   'indian',
#   'indie',
#   'indie-pop',
#   'industrial',
#   'iranian',
#   'j-dance',
#   'j-idol',
#   'j-pop',
# ...

# %%
#list of spotify recomendations based on track
sp.recommendations(seed_tracks = ["spotify:track:2EGaDf0cPX789H3LNeB03D"])['tracks'][0]['name']
# Out:
# 'Look on the Floor (Angel City Radio Edit)'

# %%
#getting artist name through the search queary
name="Usher"
sp.search(q='artist:' + name, type='artist')['artists']["items"]
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/23zg3TcAtWQy7J6upgbUnj'},
#   'followers': {'href': None, 'total': 6943982},
#   'genres': ['atl hip hop',
#    'dance pop',
#    'pop',
#    'pop rap',
#    'r&b',
#    'urban contemporary'],
#   'href': 'https://api.spotify.com/v1/artists/23zg3TcAtWQy7J6upgbUnj',
#   'id': '23zg3TcAtWQy7J6upgbUnj',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/e11ebc670e5b5fec7a765ae974e114f394236b9b',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/2d811b9a90b1fd1b9119d0f094c546bcd975c7ac',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/73442b539f375fdf6afb58492a6eaae7b93d57da',
#     'width': 160}],
#   'name': 'Usher',
#   'popularity': 83,
#   'type': 'artist',
#   'uri': 'spotify:artist:23zg3TcAtWQy7J6upgbUnj'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/66Q9dkZ7EXdwU2h6tEkUdC'},
# ...

# %%
#artist information including genre
sp.artist("23zg3TcAtWQy7J6upgbUnj")
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/23zg3TcAtWQy7J6upgbUnj'},
#  'followers': {'href': None, 'total': 6943929},
#  'genres': ['atl hip hop',
#   'dance pop',
#   'pop',
#   'pop rap',
#   'r&b',
#   'urban contemporary'],
#  'href': 'https://api.spotify.com/v1/artists/23zg3TcAtWQy7J6upgbUnj',
#  'id': '23zg3TcAtWQy7J6upgbUnj',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/e11ebc670e5b5fec7a765ae974e114f394236b9b',
#    'width': 640},
#   {'height': 320,
#    'url': 'https://i.scdn.co/image/2d811b9a90b1fd1b9119d0f094c546bcd975c7ac',
#    'width': 320},
#   {'height': 160,
#    'url': 'https://i.scdn.co/image/73442b539f375fdf6afb58492a6eaae7b93d57da',
#    'width': 160}],
#  'name': 'Usher',
#  'popularity': 83,
#  'type': 'artist',
#  'uri': 'spotify:artist:23zg3TcAtWQy7J6upgbUnj'}

# %%
#code='AQAl-iNzETI8S3lQKgpiq3_x-6C12e31Ijy-NBq7STQvTAoy3IGChfunOGDzwl7jPa9SE0NFkqv70oeKXcwYoW8t71h1IZN-tW5x3CORbOy3LfCMp9WQKLeToWZrv0NUMFhkYBwg0hy7zJyQBplVzKkGyFWkkHn4bQ9ARZYhmx6Go3LEEH39XNT7cyWjsH9BPYIny6Bml7ZPeYrNilo'

# %%
music("spotify:track:2EGaDf0cPX789H3LNeB03D","Cruel Summer","Bananarama")

# %%
df.head(1)
# Out:
#                                     id          name     artists  \
# 0  spotify:track:2EGaDf0cPX789H3LNeB03  Cruel Summer  Bananarama
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.666   0.871  1.0    -6.017   0.0       0.0272          0.27
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature
# 0            0.0208     0.263    0.936  108.501     215326.0             4.0

# %%
uri = 'PLAYLIST-LINK'
username = uri.split(':')[2]
playlist_id = uri.split(':')[4]

if token:
    sp= spotipy.Spotify(auth=token)
    results = sp.user_playlist(username,playlist_id,fields='tracks,next')
    tracks = results['tracks']
    playlist = track_info(tracks)
    
    for x in playlist:
        music(x[0],x[1],x[2])
    
else:
    print("Can't get token for", username)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-21-210a2d8e2fdf> in <module>
#       1
#       2 uri = 'PLAYLIST-LINK'
# ----> 3 username = uri.split(':')[2]
#       4 playlist_id = uri.split(':')[4]
#       5
#
# IndexError: list index out of range

# %%
birdy_uri = 'spotify:artist:2WX2uTcsvV5OnS0inACecP'
spotify = spotipy.Spotify()

results = spotify.artist_albums(birdy_uri, album_type='album')
albums = results['items']
while results['next']:
    results = spotify.next(results)
    albums.extend(results['items'])

for album in albums:
    print(album['name'])
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/spotipy-2.4.4-py3.7.egg/spotipy/client.py in _internal_call(self, method, url, payload, params)
#     118         try:
# --> 119             r.raise_for_status()
#     120         except:
#
# /anaconda3/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/artists/2WX2uTcsvV5OnS0inACecP/albums?album_type=album&limit=20&offset=0
#
# During handling of the above exception, another exception occurred:
#
# SpotifyException                          Traceback (most recent call last)
# <ipython-input-6-739b83027633> in <module>
#       2 spotify = spotipy.Spotify()
#       3
# ...
